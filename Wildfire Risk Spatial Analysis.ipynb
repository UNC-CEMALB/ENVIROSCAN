# %%
load(url("https://github.com/mgimond/Spatial/raw/main/Data/moransI.RData"))

# %%
s1
# Out:
# Loading required package: sp
#
# Warning message in wkt(x):
# “CRS object has no comment”
# Registered S3 method overwritten by 'geojsonsf':
#   method        from
#   print.geojson geojson
# An object of class "SpatialPolygonsDataFrame"
# Slot "data":
#            NAME Income   NoSchool  NoSchoolSE IncomeSE
# 0     Aroostook  21024 0.01338720 0.001406960  250.909
# 1      Somerset  21025 0.00521153 0.001150020  390.909
# 2   Piscataquis  21292 0.00633830 0.002128960  724.242
# 3     Penobscot  23307 0.00684534 0.001025450  242.424
# 4    Washington  20015 0.00478188 0.000966036  327.273
# 5      Franklin  21744 0.00508507 0.001641740  530.909
# 6        Oxford  21885 0.00700822 0.001318160  536.970
# 7         Waldo  23020 0.00498141 0.000918837  450.909
# 8      Kennebec  25652 0.00570358 0.000917087  360.000
# 9  Androscoggin  24268 0.00830953 0.001178660  460.606
# 10      Hancock  28071 0.00238996 0.000784584  585.455
# 11         Knox  27141 0.00652269 0.001863920  684.849
# 12      Lincoln  27839 0.00278315 0.001030800  571.515
# 13   Cumberland  32549 0.00494917 0.000683236  346.061
# 14    Sagadahoc  28122 0.00285524 0.000900782  544.849
# 15         York  28496 0.00529228 0.000737195  332.121
#
# Slot "polygons":
# [[1]]
# An object of class "Polygons"
# Slot "Polygons":
# [[1]]
# An object of class "Polygon"
# Slot "labpt":
# [1]  531240.3 5166755.5
#
# Slot "area":
# [1] 17620245659
#
# Slot "hole":
# [1] FALSE
#
# Slot "ringDir":
# [1] 1
#
# Slot "coords":
#           [,1]    [,2]
#  [1,] 513821.1 5138230
#  [2,] 513805.9 5157457
#  [3,] 445039.5 5157822
#  [4,] 422283.8 5157948
#  [5,] 424686.6 5171339
#  [6,] 482640.3 5255569
#  [7,] 496456.8 5252066
#  [8,] 497222.2 5233765
#  [9,] 507965.2 5225423
# [10,] 536692.3 5238280
# [11,] 546033.2 5237026
# [12,] 550232.9 5245094
# [13,] 558092.9 5244585
# [14,] 591809.0 5212652
# [15,] 594534.8 5088889
# [16,] 596500.1 5085532
# [17,] 593543.1 5081252
# [18,] 596362.4 5075663
# [19,] 593024.7 5071913
# [20,] 593188.6 5058981
# [21,] 574488.6 5054026
# [22,] 557882.4 5050346
# [23,] 557929.3 5049275
# [24,] 546205.1 5046673
# [25,] 544140.8 5048051
# [26,] 544178.1 5067533
# [27,] 544902.0 5068768
# [28,] 543386.8 5104535
# [29,] 543351.7 5136537
# [30,] 523537.6 5136854
# [31,] 523504.9 5138181
# [32,] 513821.1 5138230
#
#
#
# Slot "plotOrder":
# [1] 1
#
# Slot "labpt":
# [1]  531240.3 5166755.5
#
# Slot "ID":
# [1] "0"
#
# Slot "area":
# [1] 17620245659
#
#
# [[2]]
# An object of class "Polygons"
# Slot "Polygons":
# [[1]]
# An object of class "Polygon"
# Slot "labpt":
# [1]  425411.9 5039624.4
#
# Slot "area":
# [1] 10630951624
#
# Slot "hole":
# [1] FALSE
#
# Slot "ringDir":
# [1] 1
#
# Slot "coords":
#           [,1]    [,2]
#  [1,] 379071.8 5057518
#  [2,] 391334.9 5064114
#  [3,] 389926.1 5071725
#  [4,] 402726.4 5083591
#  [5,] 403309.8 5088651
#  [6,] 398484.0 5091414
#  [7,] 400980.1 5100750
#  [8,] 399084.2 5102281
#  [9,] 405046.7 5110052
# [10,] 400957.4 5115986
# [11,] 408331.8 5131941
# [12,] 419583.3 5141926
# [13,] 422283.8 5157948
# [14,] 445039.5 5157822
# [15,] 443529.2 5091286
# [16,] 447056.4 5091706
# [17,] 449579.6 5079146
# [18,] 447572.3 5077727
# [16,] 537491.9 4904172
# [17,] 535168.0 4900833
# [18,] 520698.9 4910373
# [19,] 514921.7 4908258
# [20,] 514826.8 4917872
# [21,] 520559.6 4928251
# [22,] 520231.6 4933252
# [23,] 514001.1 4939522
# [24,] 513967.1 4945651
# [25,] 513946.6 4948119
# [26,] 516142.3 4948208
# [27,] 518576.9 4947015
# [28,] 518520.7 4945953
# [29,] 520296.9 4945809
# [30,] 522333.2 4949662
# [31,] 525003.7 4952009
# [32,] 527770.0 4950344
# [33,] 531246.4 4954477
# [34,] 543912.1 4957021
# [35,] 539445.0 4980857
# [36,] 549160.6 4982642
# [37,] 547647.5 4992775
# [38,] 557010.3 4994683
# [39,] 554909.5 5008253
# [40,] 574529.6 5011825
#
#
# [[2]]
# An object of class "Polygon"
# Slot "labpt":
# [1]  555714.4 4910579.5
#
# Slot "area":
# [1] 250040354
#
# Slot "hole":
# [1] FALSE
#
# Slot "ringDir":
# [1] 1
#
# Slot "coords":
#           [,1]    [,2]
#  [1,] 548760.9 4913957
#  [2,] 551742.5 4916390
#  [3,] 551302.6 4919709
#  [4,] 560585.5 4920756
#  [5,] 566586.6 4909365
#  [6,] 555472.4 4904322
#  [7,] 554255.1 4897097
#  [8,] 547654.5 4902124
#  [9,] 548760.9 4913957
#
#
#
# Slot "plotOrder":
# [1] 1 2
#
# Slot "labpt":
# [1]  552034.1 4952847.6
#
# Slot "ID":
# [1] "10"
#
# Slot "area":
# [1] 4140106806
#
#
# [[12]]
# An object of class "Polygons"
# Slot "Polygons":
# [[1]]
# An object of class "Polygon"
# Slot "labpt":
# [1]  481944.3 4890411.6
#
# Slot "area":
# [1] 851761778
#
# Slot "hole":
# [1] FALSE
#
# Slot "ringDir":
# [1] 1
#
# Slot "coords":
#           [,1]    [,2]
#  [1,] 472230.8 4873705
#  [2,] 473659.6 4873162
#  [3,] 477377.3 4879705
#  [4,] 475838.4 4882421
#  [5,] 476194.2 4886203
#  [6,] 473416.8 4895321
#  [7,] 467775.7 4895721
#  [8,] 467423.7 4896754
#  [9,] 464958.7 4898355
# [10,] 464560.4 4906132
# [11,] 464904.0 4907788
# [12,] 466614.3 4907341
# [13,] 466941.8 4908694
# [14,] 468723.1 4910526
# [15,] 472446.3 4906729
# [16,] 478974.7 4912468
# [17,] 489571.3 4900756
# [18,] 496871.9 4899916
# [19,] 498284.8 4898985
# [20,] 494037.3 4879547
# [21,] 482414.9 4865986
# [22,] 476434.0 4865494
# [23,] 472230.8 4873705
#
#
#
# Slot "plotOrder":
# [1] 1
#
# Slot "labpt":
# [1]  481944.3 4890411.6
#
# Slot "ID":
# [1] "11"
#
# Slot "area":
# [1] 851761778
#
#
# [[13]]
# An object of class "Polygons"
# Slot "Polygons":
# [[1]]
# An object of class "Polygon"
# Slot "labpt":
# [1]  457346.6 4881580.3
#
# Slot "area":
# [1] 1212895068
#
# Slot "hole":
# [1] FALSE
#
# Slot "ringDir":
# [1] 1
#
# Slot "coords":
#           [,1]    [,2]
#  [1,] 435888.6 4875168
#  [2,] 438575.3 4877460
#  [3,] 437760.2 4880402
#  [4,] 440001.9 4887773
#  [5,] 447522.4 4886256
#  [6,] 446791.0 4898207
#  [7,] 448493.7 4903287
#  [8,] 456595.0 4901233
#  [9,] 458366.7 4903826
# [10,] 459766.7 4909937
# [11,] 466941.8 4908694
# [12,] 466614.3 4907341
# [13,] 464904.0 4907788
# [14,] 464560.4 4906132
# [15,] 464958.7 4898355
# [16,] 467423.7 4896754
# [17,] 467775.7 4895721
# [18,] 473416.8 4895321
# [19,] 476194.2 4886203
# [20,] 475838.4 4882421
# [21,] 477377.3 4879705
# [22,] 473659.6 4873162
# [23,] 472230.8 4873705
# [24,] 468385.6 4874739
# [25,] 461183.8 4859454
# [26,] 452628.3 4854811
# [27,] 446596.0 4855674
# [28,] 447448.9 4869888
# [29,] 450886.4 4875789
# [30,] 442163.5 4865237
# [31,] 443507.0 4873345
# [32,] 435888.6 4875168
#
#
#
# Slot "plotOrder":
# [1] 1
#
# Slot "labpt":
# [1]
]
# An object of class "Polygon"
# Slot "labpt":
# [1]  439196.8 4862613.9
#
# Slot "area":
# [1] 130950551
#
# Slot "hole":
# [1] FALSE
#
# Slot "ringDir":
# [1] 1
#
# Slot "coords":
#          [,1]    [,2]
# [1,] 435888.6 4875168
# [2,] 443507.0 4873345
# [3,] 442163.5 4865237
# [4,] 439880.0 4860303
# [5,] 441690.2 4848191
# [6,] 439600.3 4845680
# [7,] 437432.5 4848984
# [8,] 435888.6 4875168
#
#
#
# Slot "plotOrder":
# [1] 1 2
#
# Slot "labpt":
# [1]  428413.6 4873458.2
#
# Slot "ID":
# [1] "14"
#
# Slot "area":
# [1] 596940455
#
#
# [[16]]
# An object of class "Polygons"
# Slot "Polygons":
# [[1]]
# An object of class "Polygon"
# Slot "labpt":
# [1]  361579.9 4816137.4
#
# Slot "area":
# [1] 2618384147
#
# Slot "hole":
# [1] FALSE
#
# Slot "ringDir":
# [1] 1
#
# Slot "coords":
#           [,1]    [,2]
#  [1,] 341282.3 4821768
#  [2,] 342510.1 4823625
#  [3,] 341992.1 4825325
#  [4,] 340611.1 4826211
#  [5,] 340340.7 4850592
#  [6,] 343780.9 4849996
#  [7,] 346312.6 4851426
#  [8,] 356518.5 4853091
#  [9,] 357005.9 4851747
# [10,] 358870.4 4850378
# [11,] 363534.7 4851590
# [12,] 366092.7 4849828
# [13,] 367449.6 4846663
# [14,] 367045.2 4840303
# [15,] 369371.3 4839872
# [16,] 370481.5 4837785
# [17,] 371334.9 4839359
# [18,] 373276.5 4838442
# [19,] 374720.0 4841453
# [20,] 381793.8 4833571
# [21,] 379538.7 4829744
# [22,] 391600.4 4821093
# [23,] 389445.1 4809507
# [24,] 381918.7 4800655
# [25,] 375247.6 4799247
# [26,] 364433.1 4772272
# [27,] 352055.0 4775954
# [28,] 351179.1 4780118
# [29,] 352771.9 4788532
# [30,] 345751.9 4793777
# [31,] 345422.7 4796123
# [32,] 340408.4 4803386
# [33,] 339725.3 4806714
# [34,] 341261.7 4811338
# [35,] 340592.7 4814920
# [36,] 341644.7 4820026
# [37,] 341282.3 4821768
#
#
#
# Slot "plotOrder":
# [1] 1
#
# Slot "labpt":
# [1]  361579.9 4816137.4
#
# Slot "ID":
# [1] "15"
#
# Slot "area":
# [1] 2618384147
#
#
#
# Slot "plotOrder":
#  [1]  1  3  2  4  5  7  6 11 16  9 14  8 10 13 12 15
#
# Slot "bbox":
#         min       max
# x  336337.7  660529.1
# y 4772272.3 5255569.2
#
# Slot "proj4string":
# Coordinate Reference System:
# Deprecated Proj.4 representation:
#  +proj=utm +zone=19 +datum=NAD83 +units=m +no_defs +ellps=GRS80
# +towgs84=0,0,0

# %%
install.packages("spdep")
library(spdep)
# Out:
# Updating HTML index of packages in '.Library'
#
# Making 'packages.html' ...
#  done

# %%
nb = poly2nb(s1, queen = TRUE)
nb
# Out:
# Neighbour list object:
# Number of regions: 16
# Number of nonzero links: 66
# Percentage nonzero weights: 25.78125
# Average number of links: 4.125

# %%
nb[[15]] # polygon 15 has 4 neighbors
s1$NAME[[15]] # polygon 15's name is Sagadahoc
s1$NAME[nb[[15]]] # it's 4 neighbors are Kennebc, Androscoggin, Lincoln, Cumberland
# Out:
# [1]  9 10 13 14
# [1] Sagadahoc
# 16 Levels: Androscoggin Aroostook Cumberland Franklin Hancock Kennebec ... York
# [1] Kennebec     Androscoggin Lincoln      Cumberland
# 16 Levels: Androscoggin Aroostook Cumberland Franklin Hancock Kennebec ... York

# %%
lw = nb2listw(nb, style = "W", zero.policy = TRUE)
# weights from polygon 15's 4 neighbors
lw$weights[[1]]
# Out:
# [1] 0.25 0.25 0.25 0.25

# %%
Inc.lag <- lag.listw(lw, s1$Income)
head(Inc.lag)
# Out:
# [1] 21409.75 22673.17 21785.33 22407.83 24134.00 23207.50

# %%
# hesitant to use linear regression but ok
M <- lm(Inc.lag ~ s1$Income)

# %%
# computing a pseduo p value - hard
n <- 599L   # Define the number of simulations
I.r <- vector(length=n)  # Create an empty vector

for (i in 1:n){
# setting seed for reproducibility
  set.seed(7)
  # Randomly shuffle income values
  x <- sample(s1$Income, replace=FALSE)
  # Compute new set of lagged values
  x.lag <- lag.listw(lw, x)
  # Compute the regression slope and store its value
  M.r    <- lm(x.lag ~ x)
  I.r[i] <- coef(M.r)[2]
}

N.greater <- sum(coef(M)[2] > I.r)
p <- min(N.greater + 1, n + 1 - N.greater) / (n + 1)
p
# Out:
# [1] 0.025

# %%
# computing a pseduo p value - easy
MC <- moran.mc(s1$Income, lw, nsim=599)

# View results (including p-value)
MC
# Out:
# 	Monte-Carlo simulation of Moran I
#
# data:  s1$Income
# weights: lw
# number of simulations + 1: 600
#
# statistic = 0.28281, observed rank = 586, p-value = 0.02333
# alternative hypothesis: greater

# %%
setwd('/Users/alexis/Library/CloudStorage/OneDrive-UniversityofNorthCarolinaatChapelHill/CEMALB_DataAnalysisPM/Projects/P1009. NC ENVRIOSCAN/P1009.3. Analyses/P1009.3.6. Mapping')
Output = ('/Users/alexis/Library/CloudStorage/OneDrive-UniversityofNorthCarolinaatChapelHill/CEMALB_DataAnalysisPM/Projects/P1009. NC ENVRIOSCAN/P1009.3. Analyses/P1009.3.6. Mapping/Output')
cur_date = "030923"

library(readxl)
library(tidyverse)
library(reshape2)
library(sf)
library(tigris)
# library(cowplot)
# library(rcartocolor)
# library(RColorBrewer)
# library(MetBrewer)

# reading in files
whp_df = data.frame(read_excel("Input/Imputed_Wildfire_Hazard_030923.xlsx"))

# %%
head(whp_df)
# Out:
#   GEO_ID             FIPS        County Census_Tract       Avg_ACRES
# 1 14000US37141920201 37141920201 Pender 9202.01            596842.6
# 2 14000US37141920401 37141920401 Pender 9204.01            596842.6
# 3 14000US37141920402 37141920402 Pender 9204.02            596842.6
# 4 14000US37141920403 37141920403 Pender 9204.0300000000007 596842.6
# 5 14000US37141920601 37141920601 Pender 9206.01            596842.6
# 6 14000US37141990100 37141990100 Pender 9901               596842.6
#   Wildfire_Hazard_Potential_Mean
# 1 715.5177
# 2 715.5177
# 3 715.5177
# 4 715.5177
# 5 715.5177
# 6 715.5177

# %%
# download shapefile from the tigris (census package)
nc_census_tract_shapefile = tracts(state = 37, year = 2010) %>%
    rename(FIPS = GEOID10)

head(nc_census_tract_shapefile)
# Out:
#   STATEFP10 COUNTYFP10 TRACTCE10 FIPS        NAME10 NAMELSAD10        MTFCC10
# 1 37        153        970100    37153970100 9701   Census Tract 9701 G5020
# 2 37        153        970200    37153970200 9702   Census Tract 9702 G5020
# 3 37        153        970800    37153970800 9708   Census Tract 9708 G5020
# 4 37        153        970900    37153970900 9709   Census Tract 9709 G5020
# 5 37        153        971000    37153971000 9710   Census Tract 9710 G5020
# 6 37        153        971100    37153971100 9711   Census Tract 9711 G5020
#   FUNCSTAT10 ALAND10   AWATER10 INTPTLAT10  INTPTLON10   COUNTYFP STATEFP
# 1 S          246281647 2106825  +35.0503203 -079.6180454 153      37
# 2 S          457736198 7835811  +35.0967892 -079.8225512 153      37
# 3 S          139358521 2752112  +34.8508484 -079.8201950 153      37
# 4 S           23311020   78240  +34.8785679 -079.7346295 153      37
# 5 S           49233222  188190  +34.9395795 -079.6628977 153      37
# 6 S          161136716  948938  +34.8751742 -079.6567146 153      37
#   geometry
# 1 MULTIPOLYGON (((-79.56729 3...
# 2 MULTIPOLYGON (((-79.71753 3...
# 3 MULTIPOLYGON (((-79.76773 3...
# 4 MULTIPOLYGON (((-79.76773 3...
# 5 MULTIPOLYGON (((-79.69038 3...
# 6 MULTIPOLYGON (((-79.5684 34...

# %%
# first changing data type of some of the columns
whp_df$FIPS = as.character(whp_df$FIPS)

# combining data
whp_spatial_df = full_join(whp_df, nc_census_tract_shapefile)
whp_spatial_df$Wildfire_Hazard_Potential_Quintile_Number = as.character(whp_spatial_df$Wildfire_Hazard_Potential_Quintile_Number)

head(whp_spatial_df)
# Out:
# Joining, by = "FIPS"
#   GEO_ID             FIPS        County Census_Tract       Avg_ACRES
# 1 14000US37141920201 37141920201 Pender 9202.01            596842.6
# 2 14000US37141920401 37141920401 Pender 9204.01            596842.6
# 3 14000US37141920402 37141920402 Pender 9204.02            596842.6
# 4 14000US37141920403 37141920403 Pender 9204.0300000000007 596842.6
# 5 14000US37141920601 37141920601 Pender 9206.01            596842.6
# 6 14000US37141990100 37141990100 Pender 9901               596842.6
#   Wildfire_Hazard_Potential_Mean STATEFP10 COUNTYFP10 TRACTCE10 NAME10
# 1 715.5177                       37        141        920201    9202.01
# 2 715.5177                       37        141        920401    9204.01
# 3 715.5177                       37        141        920402    9204.02
# 4 715.5177                       37        141        920403    9204.03
# 5 715.5177                       37        141        920601    9206.01
# 6 715.5177                       37        141        990100    9901
#   NAMELSAD10           MTFCC10 FUNCSTAT10 ALAND10   AWATER10  INTPTLAT10
# 1 Census Tract 9202.01 G5020   S           21147417     44942 +34.4018480
# 2 Census Tract 9204.01 G5020   S           75755882     15209 +34.5055979
# 3 Census Tract 9204.02 G5020   S           65209545     12064 +34.5702392
# 4 Census Tract 9204.03 G5020   S          106488713   1076000 +34.5493899
# 5 Census Tract 9206.01 G5020   S          103459422    348628 +34.4486577
# 6 Census Tract 9901    G5020   S                  0 133298842 +34.3492469
#   INTPTLON10   COUNTYFP STATEFP geometry
# 1 -077.6218025 141      37      MULTIPOLYGON (((-77.66061 3...
# 2 -077.9462191 141      37      MULTIPOLYGON (((-77.94007 3...
# 3 -077.9912005 141      37      MULTIPOLYGON (((-77.92338 3...
# 4 -077.8690183 141      37      MULTIPOLYGON (((-77.83308 3...
# 5 -077.9634232 141      37      MULTIPOLYGON (((-77.94027 3...
# 6 -077.6031266 141      37      MULTIPOLYGON (((-77.67696 3...

# %%
# need to transform this into a sf object 
whp_spatial_sf = st_as_sf(whp_spatial_df)
head(whp_spatial_sf)
# Out:
#   GEO_ID             FIPS        County Census_Tract       Avg_ACRES
# 1 14000US37141920201 37141920201 Pender 9202.01            596842.6
# 2 14000US37141920401 37141920401 Pender 9204.01            596842.6
# 3 14000US37141920402 37141920402 Pender 9204.02            596842.6
# 4 14000US37141920403 37141920403 Pender 9204.0300000000007 596842.6
# 5 14000US37141920601 37141920601 Pender 9206.01            596842.6
# 6 14000US37141990100 37141990100 Pender 9901               596842.6
#   Wildfire_Hazard_Potential_Mean STATEFP10 COUNTYFP10 TRACTCE10 NAME10
# 1 715.5177                       37        141        920201    9202.01
# 2 715.5177                       37        141        920401    9204.01
# 3 715.5177                       37        141        920402    9204.02
# 4 715.5177                       37        141        920403    9204.03
# 5 715.5177                       37        141        920601    9206.01
# 6 715.5177                       37        141        990100    9901
#   NAMELSAD10           MTFCC10 FUNCSTAT10 ALAND10   AWATER10  INTPTLAT10
# 1 Census Tract 9202.01 G5020   S           21147417     44942 +34.4018480
# 2 Census Tract 9204.01 G5020   S           75755882     15209 +34.5055979
# 3 Census Tract 9204.02 G5020   S           65209545     12064 +34.5702392
# 4 Census Tract 9204.03 G5020   S          106488713   1076000 +34.5493899
# 5 Census Tract 9206.01 G5020   S          103459422    348628 +34.4486577
# 6 Census Tract 9901    G5020   S                  0 133298842 +34.3492469
#   INTPTLON10   COUNTYFP STATEFP geometry
# 1 -077.6218025 141      37      MULTIPOLYGON (((-77.66061 3...
# 2 -077.9462191 141      37      MULTIPOLYGON (((-77.94007 3...
# 3 -077.9912005 141      37      MULTIPOLYGON (((-77.92338 3...
# 4 -077.8690183 141      37      MULTIPOLYGON (((-77.83308 3...
# 5 -077.9634232 141      37      MULTIPOLYGON (((-77.94027 3...
# 6 -077.6031266 141      37      MULTIPOLYGON (((-77.67696 3...

# %%
library(tmap)

# %%
tm_shape(whp_spatial_sf) + 
  tm_fill("Wildfire_Hazard_Potential_Mean",
          palette = "Reds", 
          style = "quantile", 
          title = "% with a Qualification") +
  tm_borders(alpha=.4)
# Out:
# Error in tm_shape(whp_spatial_sf): could not find function "tm_shape"
# Traceback:

# %%
neighbors = poly2nb(whp_spatial_sf)
neighbors
# Out:
# Neighbour list object:
# Number of regions: 2195
# Number of nonzero links: 13612
# Percentage nonzero weights: 0.2825224
# Average number of links: 6.201367

# %%
neighbors[[1]] # polygon 1 has 6 neighbors
whp_spatial_sf$GEO_ID[[1]] # geo id for this region (polygon)
whp_spatial_sf$GEO_ID[neighbors[[1]]] # geo ids for this region's neighbors
# Out:
# [1]  47  48  49 137 138 139
# [1] "14000US37141920201"
# [1] "14000US37141920102" "14000US37141920103" "14000US37141920204"
# [4] "14000US37141920101" "14000US37141920202" "14000US37141920203"

# %%
# weight matrix
listw = nb2listw(neighbors)
listw
# Out:
# Characteristics of weights list object:
# Neighbour list object:
# Number of regions: 2195
# Number of nonzero links: 13612
# Percentage nonzero weights: 0.2825224
# Average number of links: 6.201367
#
# Weights style: W
# Weights constants summary:
#      n      nn   S0       S1       S2
# W 2195 4818025 2195 736.9648 9000.876

# %%
# global moran test
global_moran = moran.test(whp_spatial_df$Wildfire_Hazard_Potential_Mean, listw)
global_moran

# our p value is sig and our moran statistic shows positive autocorrelated in NC meaning that the data does 
# spatially cluster
# p value only
global_moran$p.value
# Out:
# 	Moran I test under randomisation
#
# data:  whp_spatial_df$Wildfire_Hazard_Potential_Mean
# weights: listw
#
# Moran I statistic standard deviate = 74.765, p-value < 2.2e-16
# alternative hypothesis: greater
# sample estimates:
# Moran I statistic       Expectation          Variance
#      0.9220168766     -0.0004557885      0.0001522343
# [1] 0

# %%
#not sure what exactly this means
moran.plot(whp_spatial_df$Wildfire_Hazard_Potential_Mean, listw = nb2listw(neighbors, style = "W"))
# Out:
# plot without title

# %%
# local moran
local <- localmoran(x = whp_spatial_df$Wildfire_Hazard_Potential_Mean, listw = nb2listw(neighbors, style = "W"))
head(local)
# Out:
#   Ii        E.Ii         Var.Ii   Z.Ii     Pr(z != E(Ii))
# 1 11.357551 -0.008532566 3.087806 6.468236 9.915387e-11
# 2 17.342329 -0.008532566 4.635943 8.058459 7.726244e-16
# 3 14.009781 -0.008532566 4.635943 6.510686 7.480857e-11
# 4 14.044451 -0.008532566 3.087806 7.997303 1.271745e-15
# 5 12.782130 -0.008532566 3.087806 7.278938 3.364577e-13
# 6  8.903252 -0.008532566 3.087806 5.071538 3.946143e-07

# %%
quadrant <- vector(mode="numeric",length=nrow(local))

# centers the variable of interest around its mean
m.qualification <- whp_spatial_df$Wildfire_Hazard_Potential_Mean - mean(whp_spatial_df$Wildfire_Hazard_Potential_Mean)     

# centers the local Moran's around the mean
m.local <- local[,1] - mean(local[,1])    

# significance threshold
signif <- 0.05 

# builds a data quadrant
quadrant[m.qualification >0 & m.local>0] <- 4  
quadrant[m.qualification <0 & m.local<0] <- 1      
quadrant[m.qualification <0 & m.local>0] <- 2
quadrant[m.qualification >0 & m.local<0] <- 3
quadrant[local[,5]>signif] <- 0

# %%
brks <- c(0,1,2,3,4)
colors <- c("white","blue",rgb(0,0,1,alpha=0.4),rgb(1,0,0,alpha=0.4),"red")
plot(whp_spatial_df,border="lightgray",col=colors[findInterval(quadrant,brks,all.inside=FALSE)])
box()
legend("bottomleft", legend = c("insignificant","low-low","low-high","high-low","high-high"),
       fill=colors,bty="n")
# Out:
# Error in data.matrix(x): 'list' object cannot be coerced to type 'double'
# Traceback:
#
# 1. plot(whp_spatial_df, border = "lightgray", col = colors[findInterval(quadrant,
#  .     brks, all.inside = FALSE)])
# 2. plot(whp_spatial_df, border = "lightgray", col = colors[findInterval(quadrant,
#  .     brks, all.inside = FALSE)])
# 3. plot.data.frame(whp_spatial_df, border = "lightgray", col = colors[findInterval(quadrant,
#  .     brks, all.inside = FALSE)])
# 4. pairs(data.matrix(x), ...)
# 5. data.matrix(x)
