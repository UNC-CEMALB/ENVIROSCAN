# %%
setwd('/Users/alexis/Library/CloudStorage/OneDrive-UniversityofNorthCarolinaatChapelHill/CEMALB_DataAnalysisPM/Projects/P1009. NC ENVRIOSCAN/P1009.3. Analyses/P1009.3.2. Sociodemographic Imputation/Input')
Output = ('/Users/alexis/Library/CloudStorage/OneDrive-UniversityofNorthCarolinaatChapelHill/CEMALB_DataAnalysisPM/Projects/P1009. NC ENVRIOSCAN/P1009.3. Analyses/P1009.3.2. Sociodemographic Imputation/Output')
cur_date = "123022"

library(readxl)
library(tidyverse)
library(reshape2)
library(missForest)

# reading in files
acs_df = data.frame(read_excel("ACS_Data_121222.xlsx", sheet = 2))
# need to make some of the cols numeric
acs_df[,4:30] = apply(acs_df[,4:30], 2, as.numeric)
wildfire_hazard_df = data.frame(read_excel("Wildfire_Hazard_121222.xlsx", sheet = 2))
# Out:
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.2 ──
# ✔ ggplot2 3.3.6      ✔ purrr   0.3.4
# ✔ tibble  3.1.8      ✔ dplyr   1.0.10
# ✔ tidyr   1.2.1      ✔ stringr 1.4.1
# ✔ readr   2.1.2      ✔ forcats 0.5.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
#
# Attaching package: ‘reshape2’
#
#
# The following object is masked from ‘package:tidyr’:
#
#     smiths
#
#
# Warning message in apply(acs_df[, 4:30], 2, as.numeric):
# “NAs introduced by coercion”
# Warning message in apply(acs_df[, 4:30], 2, as.numeric):
# “NAs introduced by coercion”
# Warning message in apply(acs_df[, 4:30], 2, as.numeric):
# “NAs introduced by coercion”
# Warning message in apply(acs_df[, 4:30], 2, as.numeric):
# “NAs introduced by coercion”
# Warning message in apply(acs_df[, 4:30], 2, as.numeric):
# “NAs introduced by coercion”
# Warning message in apply(acs_df[, 4:30], 2, as.numeric):
# “NAs introduced by coercion”
# Warning message in apply(acs_df[, 4:30], 2, as.numeric):
# “NAs introduced by coercion”
# Warning message in apply(acs_df[, 4:30], 2, as.numeric):
# “NAs introduced by coercion”
# Warning message in apply(acs_df[, 4:30], 2, as.numeric):
# “NAs introduced by coercion”
# Warning message in apply(acs_df[, 4:30], 2, as.numeric):
# “NAs introduced by coercion”
# Warning message in apply(acs_df[, 4:30], 2, as.numeric):
# “NAs introduced by coercion”
# Warning message in apply(acs_df[, 4:30], 2, as.numeric):
# “NAs introduced by coercion”
# Warning message in apply(acs_df[, 4:30], 2, as.numeric):
# “NAs introduced by coercion”
# Warning message in apply(acs_df[, 4:30], 2, as.numeric):
# “NAs introduced by coercion”
# Warning message in apply(acs_df[, 4:30], 2, as.numeric):
# “NAs introduced by coercion”
# Warning message in apply(acs_df[, 4:30], 2, as.numeric):
# “NAs introduced by coercion”
# Warning message in apply(acs_df[, 4:30], 2, as.numeric):
# “NAs introduced by coercion”
# Warning message in apply(acs_df[, 4:30], 2, as.numeric):
# “NAs introduced by coercion”
# Warning message in apply(acs_df[, 4:30], 2, as.numeric):
# “NAs introduced by coercion”
# Warning message in apply(acs_df[, 4:30], 2, as.numeric):
# “NAs introduced by coercion”
# Warning message in apply(acs_df[, 4:30], 2, as.numeric):
# “NAs introduced by coercion”
# Warning message in apply(acs_df[, 4:30], 2, as.numeric):
# “NAs introduced by coercion”
# Warning message in apply(acs_df[, 4:30], 2, as.numeric):
# “NAs introduced by coercion”
# Warning message in apply(acs_df[, 4:30], 2, as.numeric):
# “NAs introduced by coercion”
# Warning message in apply(acs_df[, 4:30], 2, as.numeric):
# “NAs introduced by coercion”
# Warning message in apply(acs_df[, 4:30], 2, as.numeric):
# “NAs introduced by coercion”
# Warning message in apply(acs_df[, 4:30], 2, as.numeric):
# “NAs introduced by coercion”

# %%
head(acs_df)
head(wildfire_hazard_df)
# Out:
#   GEO_ID             Census_Tract County   Sex_Ratio Median_Age
# 1 14000US37001020100 201.00       Alamance 87.2      37.3
# 2 14000US37001020200 202.00       Alamance 78.3      31.0
# 3 14000US37001020300 203.00       Alamance 77.8      40.7
# 4 14000US37001020400 204.00       Alamance 78.1      30.5
# 5 14000US37001020501 205.01       Alamance 92.7      35.1
# 6 14000US37001020502 205.02       Alamance 99.0      32.1
#   Population_Under_18 Population_Over_18 Population_Over_65 Race_White
# 1 21.9                78.1               15.1               61.0
# 2 29.1                70.9               11.2               51.9
# 3 27.1                72.9               18.9               45.2
# 4 31.4                68.6               10.1               19.6
# 5 23.3                76.7               15.6               76.1
# 6 30.0                70.0                8.9               40.7
#   Race_Black ⋯ Poverty_Adult Poverty_Elderly Poverty_Male Poverty_Female
# 1 28.5       ⋯ 20.8          14.6            26.4         28.0
# 2 29.2       ⋯ 33.0          19.2            27.3         37.8
# 3 28.9       ⋯ 17.3          22.0            18.0         28.3
# 4 59.0       ⋯ 26.8          14.0            30.0         33.3
# 5 13.3       ⋯ 12.2           7.1            12.3         14.8
# 6 35.7       ⋯ 22.3          19.2            17.7         31.0
#   Poverty_Black Poverty_Asian Poverty_Other_Race Poverty_Mixed_Race
# 1 54.8            0           45.3                 0.0
# 2 44.6            0            0.0                82.7
# 3 21.0           NA           10.9                36.4
# 4 19.9           NA           69.0               100.0
# 5 18.9            0            0.0                53.1
# 6 27.8          100           14.2                19.5
#   Poverty_Hispanic_Latino Poverty_White
# 1 31.3                    13.9
# 2 16.2                    39.0
# 3 26.7                    20.1
# 4 67.2                    26.6
# 5 25.7                    10.0
# 6 14.7                    25.0
#   GEO_ID             Census_Tract County   Avg_ACRES
# 1 14000US37001020100 201.00       Alamance 278233.79700000002
# 2 14000US37001020200 202.00       Alamance 278233.79700000002
# 3 14000US37001020301 203.01       Alamance 278233.79700000002
# 4 14000US37001020302 203.02       Alamance 278233.79700000002
# 5 14000US37001020400 204.00       Alamance 278233.79700000002
# 6 14000US37001020501 205.01       Alamance 278233.79700000002
#   Wildfire_Hazard_Potential_Mean Wildfire_Hazard_Potential_Quintile_Number
# 1 92.237034639041696             1
# 2 92.237034639041696             1
# 3 92.237034639041696             1
# 4 92.237034639041696             1
# 5 92.237034639041696             1
# 6 92.237034639041696             1
#   Wildfire_Hazard_Potential_Quintile_Percentage
# 1 0-20%
# 2 0-20%
# 3 0-20%
# 4 0-20%
# 5 0-20%
# 6 0-20%

# %%
# seeing if the census tracts are consistent each file
length(unique(acs_df$Census_Tract))
length(unique(wildfire_hazard_df$Census_Tract))
# Out:
# [1] 1410
# [1] 1776

# %%
# they're not so what tracts aren't consistent?
`%notin%` <- Negate(`%in%`)
wildfire_hazard_df %>%
    filter(Census_Tract %notin% unique(acs_df$Census_Tract)) %>%
    select(c("GEO_ID", "Census_Tract", "County")) %>%
    head()
# Out:
#   GEO_ID             Census_Tract County
# 1 14000US37007920302 9203.02      Anson
# 2 14000US37007980000 9800.00      Anson
# 3 14000US37019020107  201.07      Brunswick
# 4 14000US37019020108  201.08      Brunswick
# 5 14000US37019020205  202.05      Brunswick
# 6 14000US37019020206  202.06      Brunswick

# %%
# lot's of missing data
dim(full_join(acs_df, wildfire_hazard_df))
dim(inner_join(acs_df, wildfire_hazard_df))
# Out:
# Joining, by = c("GEO_ID", "Census_Tract", "County")
# [1] 3137   34
# Joining, by = c("GEO_ID", "Census_Tract", "County")
# [1] 1730   34

# %%
acs_whp_df = inner_join(acs_df, wildfire_hazard_df)

# need to make some of the cols numeric
acs_whp_df[,30:33] = apply(acs_whp_df[,30:33], 2, as.numeric)
head(acs_whp_df)
# Out:
# Joining, by = c("GEO_ID", "Census_Tract", "County")
# Warning message in apply(acs_whp_df[, 30:33], 2, as.numeric):
# “NAs introduced by coercion”
# Warning message in apply(acs_whp_df[, 30:33], 2, as.numeric):
# “NAs introduced by coercion”
# Warning message in apply(acs_whp_df[, 30:33], 2, as.numeric):
# “NAs introduced by coercion”
#   GEO_ID             Census_Tract County   Sex_Ratio Median_Age
# 1 14000US37001020100 201.00       Alamance 87.2      37.3
# 2 14000US37001020200 202.00       Alamance 78.3      31.0
# 3 14000US37001020400 204.00       Alamance 78.1      30.5
# 4 14000US37001020501 205.01       Alamance 92.7      35.1
# 5 14000US37001020502 205.02       Alamance 99.0      32.1
# 6 14000US37001020601 206.01       Alamance 97.3      51.7
#   Population_Under_18 Population_Over_18 Population_Over_65 Race_White
# 1 21.9                78.1               15.1               61.0
# 2 29.1                70.9               11.2               51.9
# 3 31.4                68.6               10.1               19.6
# 4 23.3                76.7               15.6               76.1
# 5 30.0                70.0                8.9               40.7
# 6 17.5                82.5               27.8               96.9
#   Race_Black ⋯ Poverty_Black Poverty_Asian Poverty_Other_Race
# 1 28.5       ⋯ 54.8            0            45.3
# 2 29.2       ⋯ 44.6            0             0.0
# 3 59.0       ⋯ 19.9           NA            69.0
# 4 13.3       ⋯ 18.9            0             0.0
# 5 35.7       ⋯ 27.8          100            14.2
# 6  0.9       ⋯  0.0            0           100.0
#   Poverty_Mixed_Race Poverty_Hispanic_Latino Poverty_White Avg_ACRES
# 1   0.0              31.3                    13.9          278233.8
# 2  82.7              16.2                    39.0          278233.8
# 3 100.0              67.2                    26.6          278233.8
# 4  53.1              25.7                    10.0          278233.8
# 5  19.5              14.7                    25.0          278233.8
# 6   0.0               6.7                     3.6          278233.8
#   Wildfire_Hazard_Potential_Mean Wildfire_Hazard_Potential_Quintile_Number
# 1 92.23703                       1
# 2 92.23703                       1
# 3 92.23703                       1
# 4 92.23703                       1
# 5 92.23703                       1
# 6 92.23703                       1
#   Wildfire_Hazard_Potential_Quintile_Percentage
# 1 0-20%
# 2 0-20%
# 3 0-20%
# 4 0-20%
# 5 0-20%
# 6 0-20%

# %% [markdown]
# # Variable Filtering
# RF imputation needs at least 25% of data in order to impute the missing data, therefore variables with less than 50% won't be imputed. This filtering will be done within each county.

# %%
# only keeping variables with at least 25% of data in each county
variable_presence_df = acs_whp_df[,1:31] %>% 
    pivot_longer(cols = 4:31, names_to = "Variable", values_to = "Value") %>%
    # creating 2 count cols: 1st for non-missing data, 2nd for all data
    mutate(data_count = ifelse(is.na(Value), 0, 1), all_count = 1) %>%
    group_by(County, Variable) %>%
    summarize(Variable_Presence = sum(data_count)/ sum(all_count) * 100) %>%
    filter(Variable_Presence > 25) %>%
    arrange(-Variable_Presence)
    #select(-Census_Tract) %>%
    #unique()

head(variable_presence_df)
# Out:
# `summarise()` has grouped output by 'County'. You can override using the
# `.groups` argument.
#   County   Variable                        Variable_Presence
# 1 Alamance Avg_ACRES                       100
# 2 Alamance English_Speakers_Only           100
# 3 Alamance Hispanic_Latino                 100
# 4 Alamance Median_Age                      100
# 5 Alamance Non_Proficient_English_Speakers 100
# 6 Alamance Population_Over_18              100

# %% [markdown]
# # Random Forest Imputation
# Generating missing values using random forest (RF).

# %%
b = variable_presence_df %>% filter (County == "Ashe")
keeping = c(colnames(acs_whp_df)[1:3], b$Variable)

acs_whp_df[,keeping]
# Out:
#      GEO_ID             Census_Tract County   Avg_ACRES English_Speakers_Only
# 1    14000US37001020100 201.00       Alamance 278233.8  87.6
# 2    14000US37001020200 202.00       Alamance 278233.8  68.3
# 3    14000US37001020400 204.00       Alamance 278233.8  80.8
# 4    14000US37001020501 205.01       Alamance 278233.8  86.9
# 5    14000US37001020502 205.02       Alamance 278233.8  75.6
# 6    14000US37001020601 206.01       Alamance 278233.8  93.7
# 7    14000US37001020602 206.02       Alamance 278233.8  97.6
# 8    14000US37001020701 207.01       Alamance 278233.8  90.0
# 9    14000US37001020702 207.02       Alamance 278233.8  87.7
# 10   14000US37001020801 208.01       Alamance 278233.8  83.0
# 11   14000US37001020802 208.02       Alamance 278233.8  69.0
# 12   14000US37001020901 209.01       Alamance 278233.8  81.3
# 13   14000US37001020902 209.02       Alamance 278233.8  87.7
# 14   14000US37001021000 210.00       Alamance 278233.8  78.5
# 15   14000US37001021101 211.01       Alamance 278233.8  92.2
# 16   14000US37001021102 211.02       Alamance 278233.8  92.1
# 17   14000US37001021201 212.01       Alamance 278233.8  82.8
# 4    14.5            35.1        9.9
# 5    23.5            32.1       13.2
# 6     3.6            51.7        0.8
# 7     6.5            49.2        0.9
# 8     9.1            47.2        2.2
# 9    17.9            36.9        5.4
# 10   17.0            41.7        9.9
# 11   35.4            39.9       17.2
# 12   21.7            40.4        8.5
# 13    9.1            46.4        4.0
# 14   24.7            30.4        7.2
# 15    5.7            41.2        1.4
# 16    9.9            38.6        2.0
# 17   19.2            37.5        9.9
# 18   10.3            40.7        3.9
# 19    5.3            34.7        2.3
# 20    8.0            32.1        3.8
# 21   10.8            40.3        0.0
# 22    4.2            47.3        1.6
# 23    5.1            46.7        2.1
# 24    4.9            45.7        2.2
# 25    5.7            22.9        0.1
# 26    1.5            57.9        1.0
# 27    7.3            22.8        4.8
# 28    2.7            35.4        5.9
# 29    2.6            45.8        0.5
# 30    0.5            40.8        0.3
# ⋮    ⋮               ⋮          ⋮
# 1701 13.9            40.1       4.7
# 1702 12.8            43.1       4.2
# 1703  4.7            42.3       0.3
# 1704  6.2            47.4       0.8
# 1705  3.7            54.6       1.3
# 1706  7.2            42.9       3.4
# 1707 10.5            48.3       4.5
# 1708 14.3            34.5       5.6
# 1709 17.6            28.3       8.6
# 1710 18.6            39.3       9.9
# 1711  0.5            49.7       0.8
# 1712  1.0            46.4       0.0
# 1713 26.3            31.2       5.5
# 1714 23.7            34.9       4.5
# 1715  7.1            40.8       1.7
# 1716  3.2            46.8       0.4
# 1717 12.0            51.2       8.9
# 1718 14.6            47.8       3.5
# 1719 15.0            37.9       7.6
# 1720 10.3            44.9       4.8
# 1721  8.9            42.8       4.2
# 1722  9.9            44.4       3.1
# 1723  4.3            49.0       3.0
# 1724  8.4            42.9       1.9
# 1725 11.0            44.3       4.2
# 1726  7.3            45.9       1.7
# 1727 10.4            45.3       3.8
# 1728  6.2            50.9       3.8
# 1729  2.5            51.2       1.8
# 1730  1.7            45.7       0.0
#      Population_Over_18 Population_Over_65 ⋯ Race_Black Race_Indigenous
# 1    78.1               15.1               ⋯ 28.5       0.3
# 2    70.9               11.2               ⋯ 29.2       0.9
# 3    68.6               10.1               ⋯ 59.0       0.2
# 4    76.7               15.6               ⋯ 13.3       0.0
# 5    70.0                8.9               ⋯ 35.7       0.0
# 6    82.5               27.8               ⋯  0.9       0.2
# 7    83.2               30.8               ⋯  3.7       0.0
# 8    83.5               22.0               ⋯ 11.8       0.8
# 9    78.6               16.5               ⋯ 31.3       0.0
# 10   77.8               18.1               ⋯ 17.6       0.1
# 11   74.6               14.7               ⋯ 37.5       0.0
# 12   74.2               16.9               ⋯ 12.7       0.4
# 13   79.2               22.2               ⋯ 12.1       0.0
# 14   69.2               12.9               ⋯ 36.5       0.7
# 15   79.8               16.7               ⋯ 29.9       1.7
# 16   78.2               19.3               ⋯ 24.4       0.7
# 17   76.7               18.9               ⋯ 27.0       0.2
# 18   75.9               14.9               ⋯ 15.5       0.8
# 19   75.9               11.8               ⋯ 27.9       0.0
# 20   69.7                9.8               ⋯ 27.0       0.2
# 21   73.5               16.8               ⋯  7.5       0.4
# 22   80.7               18.6               ⋯ 28.1       0.7
# 23   83.0               15.7               ⋯  4.8       0.3
# 24   75.5               15.1               ⋯  7.7       0.2
# 25   85.2               13.8               ⋯ 11.7       0.1
# 26   85.4               39.8               ⋯  9.3       0.1
# 27   86.4               13.9               ⋯  6.8       0.0
# 28   82.0               16.1               ⋯ 14.2       0.6
# 29   79.2               21.6               ⋯  6.1       0.8
# 30   76.4               14.4               ⋯  2.8       0.1
# ⋮    ⋮                  ⋮                  ⋱ ⋮          ⋮
# 1701 78.2               19.2               ⋯ 14.7       0.0
# 1702 78.8               20.1               ⋯  1.6       1.7
# 1703 77.2               16.3               ⋯  0.2       1.4
# 1704 77.9               20.9               ⋯  0.0       0.7
# 1705 88.3               29.3               ⋯  4.6       0.5
# 1706 79.2               25.0               ⋯  3.5       0.8
# 1707 81.7               28.5               ⋯ 12.6       0.4
# 1708 82.4               11.6               ⋯ 63.8       0.0
# 1709 74.8                7.6               ⋯ 73.4       0.0
# 1710 73.2               13.6               ⋯ 68.5       5.0
# 1711 81.0               27.4               ⋯ 15.4       0.0
# 1712 80.5               19.1               ⋯ 41.1       0.0
# 1713 74.9               14.4               ⋯ 72.0       2.1
# 1714 72.1               14.5               ⋯ 55.5       2.5
# 1715 75.8               17.3               ⋯ 18.6       0.0
# 1716 80.8               20.4               ⋯ 42.8       0.0
# 1717 84.7               16.6               ⋯ 36.3       0.0
# 1718 77.4               17.2               ⋯ 31.0       0.9
# 1719 75.1               13.9               ⋯ 22.8       0.4
# 1720 78.0               17.8               ⋯ 17.5       0.3
# 1721 77.7               14.9               ⋯  1.2       0.0
# 1722 77.7               17.5               ⋯  2.2       0.0
# 1723 83.4               22.7               ⋯  5.5       0.0
# 1724 76.8               20.4               ⋯  8.7       0.0
# 1725 81.9               19.3               ⋯  2.2       0.6
# 1726 79.6               24.3               ⋯  0.0       0.6
# 1727 80.5               21.6               ⋯  0.0       1.6
# 1728 83.5               32.1               ⋯  0.6       0.1
# 1729 82.4               23.4               ⋯  2.4       0.3
# 1730 80.5               22.0               ⋯  0.4       0.6
#      Race_Mixed Race_Other Race_White Sex_Ratio Poverty_Black
# 1    1.9         6.5       61.0        87.2     54.8
# 2    1.8        11.7       51.9        78.3     44.6
# 3    1.4        19.9       19.6        78.1     19.9
# 4    0.8         8.3       76.1        92.7     18.9
# 5    6.2        15.1       40.7        99.0     27.8
# 6    1.3         0.2       96.9        97.3      0.0
# 7    0.6         0.5       94.3        93.3      0.0
# 8    3.7         0.6       82.7        99.7     16.6
# 9    0.5        10.9       57.3       114.4     52.2
# 10   3.7         4.8       70.4        84.8     25.9
# 11   0.7        19.5       40.4        81.9     46.3
# 12   3.1        12.4       68.2        89.6      5.3
# 13   1.2         3.8       82.8        89.3     15.0
# 15   17.7                                 0.0           0.0
# 16   25.3                                61.5          37.0
# 17   57.6                               100.0           7.6
# 18   39.2                                  NA          79.3
# 19   23.4                                 0.0           0.0
# 20   86.6                                  NA            NA
# 21    0.0                                 0.0           0.0
# 22   37.6                                 0.0          44.2
# 23   52.8                                  NA           0.0
# 24   79.2                                  NA           3.5
# 25    2.9                                 0.0          47.4
# 26   20.2                                 0.0           0.0
# 27   49.7                                42.5         100.0
# 28   38.8                                 8.6           0.0
# 29   26.4                                  NA           0.0
# 30   42.9                                 0.0           0.0
# ⋮    ⋮                                  ⋮             ⋮
# 1701 65.8                                NA            83.8
# 1702 31.7                                 0            62.1
# 1703 10.8                                NA            65.0
# 1704 19.3                                NA             3.7
# 1705 42.0                                 0           100.0
# 1706 34.3                                 0              NA
# 1707 57.4                                 0            46.3
# 1708 39.1                                NA            13.1
# 1709 52.5                                NA             0.0
# 1710 58.2                                NA             0.0
# 1711 23.6                                 0              NA
# 1712  0.0                                 0              NA
# 1713 22.4                               100            23.8
# 1714 23.8                                 0            71.6
# 1715 35.6                                NA            29.4
# 1716 19.4                                NA             0.0
# 1717 70.7                                NA             0.0
# 1718 28.2                               100            38.0
# 1719 53.5                                 0            56.9
# 1720 44.3                                 0            18.2
# 1721 57.9                                NA             0.0
# 1722 69.8                                NA              NA
# 1723 70.3                                NA            73.9
# 1724 27.7                                 0             0.0
# 1725 40.3                                NA             0.0
# 1726 30.2                                 0             0.0
# 1727 42.9                                80             0.0
# 1728 90.9                                 0             0.0
# 1729 33.8                                 0              NA
# 1730  0.0                                 0              NA

# %%
a = acs_whp_df[,keeping] %>% 
 filter(County == "Ashe")

# test
#a[a == NA] = " "
matrix_a = as.matrix(a[,4:length(keeping)])
matrix_a

missForest(matrix_a)
# Out:
#      Avg_ACRES English_Speakers_Only Hispanic_Latino Median_Age
# [1,] 274732.1   93.9                 6.3             45.1
# [2,] 237671.3  100.0                 0.5             51.2
# [3,] 274732.1   92.6                 6.8             46.3
#      Non_Proficient_English_Speakers Population_Over_18 Population_Over_65
# [1,] 0.6                             83.4               21.8
# [2,] 0.0                             82.1               26.1
# [3,] 1.4                             78.1               21.5
#      Population_Under_18 Poverty_Adult Poverty_Children ⋯ Race_Black
# [1,] 16.6                18.1          25.8             ⋯ 0.7
# [2,] 17.9                24.9          54.8             ⋯ 0.0
# [3,] 21.9                15.7          20.0             ⋯ 0.9
#      Race_Indigenous Race_Mixed Race_Other Race_White Sex_Ratio Poverty_Black
# [1,] 0.2             2.4        0.0        96.7       109.3      0
# [2,] 0.7             1.0        0.0        98.3       106.0     NA
# [3,] 0.0             2.3        0.8        94.8        89.5     80
#      Proficient_in_Non_English_Language Poverty_Asian Poverty_Other_Race
# [1,]  9.1                                NA             NA
# [2,]   NA                                NA             NA
# [3,] 19.6                               3.9           16.7
# Warning message in randomForest.default(x = obsX, y = obsY, ntree = ntree, mtry = mtry, :
# “The response has five or fewer unique values.  Are you sure you want to do regression?”
# Warning message in randomForest.default(x = obsX, y = obsY, ntree = ntree, mtry = mtry, :
# “The response has five or fewer unique values.  Are you sure you want to do regression?”
# Warning message in randomForest.default(x = obsX, y = obsY, ntree = ntree, mtry = mtry, :
# “The response has five or fewer unique values.  Are you sure you want to do regression?”
# Error in if (n == 0) stop("data (x) has 0 rows"): argument is of length zero
# Traceback:
#
# 1. missForest(matrix_a)
# 2. randomForest(x = obsX, y = obsY, ntree = ntree, mtry = mtry,
#  .     replace = replace, sampsize = if (!is.null(sampsize)) sampsize[[varInd]] else if (replace) nrow(obsX) else ceiling(0.632 *
#  .         nrow(obsX)), nodesize = if (!is.null(nodesize)) nodesize[1] else 1,
#  .     maxnodes = if (!is.null(maxnodes)) maxnodes else NULL)
# 3. randomForest.default(x = obsX, y = obsY, ntree = ntree, mtry = mtry,
#  .     replace = replace, sampsize = if (!is.null(sampsize)) sampsize[[varInd]] else if (replace) nrow(obsX) else ceiling(0.632 *
#  .         nrow(obsX)), nodesize = if (!is.null(nodesize)) nodesize[1] else 1,
#  .     maxnodes = if (!is.null(maxnodes)) maxnodes else NULL)

# %%
# imputing sociodemographic data using RF
random_forest_imputation = function(preimputed_df, presence_df){
    
    imputed_df = data.frame()
    # iterating through each df grouped by county 
    for (i in 1:length(unique(preimputed_df$County))){ 
        
        # variable presence df first
        county_variable_presence_df = presence_df %>%
            filter(County == unique(preimputed_df$County)[i])
        variables_to_keep = c(colnames(preimputed_df)[1:3], county_variable_presence_df$Variable)
        
        # then the preimputed df
        county_preimputed_df = preimputed_df[,variables_to_keep] %>%
            filter(County == unique(preimputed_df$County)[i])
        print(unique(preimputed_df$County)[i])
        
        imputed_RF_object = missForest(as.matrix(county_preimputed_df[,4:length(variables_to_keep)]))
        imputed_RF_df = imputed_RF_object$ximp
        #imputed_values_df = data.frame(cbind(county_preimputed_df[,c(1:3,33,34)], imputed_RF_df)) 

        # saving imputed values
        #imputed_df = rbind(imputed_df, imputed_values_df)

    }
    
    #return(imputed_final_df)
}

# calling function
imputed_df = random_forest_imputation(acs_whp_df, variable_presence_df)
head(imputed_df)
# Out:
# [1] "Alamance"
# [1] "Alexander"
# Warning message in randomForest.default(x = obsX, y = obsY, ntree = ntree, mtry = mtry, :
# “The response has five or fewer unique values.  Are you sure you want to do regression?”
# Warning message in randomForest.default(x = obsX, y = obsY, ntree = ntree, mtry = mtry, :
# “The response has five or fewer unique values.  Are you sure you want to do regression?”
# Warning message in randomForest.default(x = obsX, y = obsY, ntree = ntree, mtry = mtry, :
# “The response has five or fewer unique values.  Are you sure you want to do regression?”
# Warning message in randomForest.default(x = obsX, y = obsY, ntree = ntree, mtry = mtry, :
# “The response has five or fewer unique values.  Are you sure you want to do regression?”
# Warning message in randomForest.default(x = obsX, y = obsY, ntree = ntree, mtry = mtry, :
# “The response has five or fewer unique values.  Are you sure you want to do regression?”
# Warning message in randomForest.default(x = obsX, y = obsY, ntree = ntree, mtry = mtry, :
# “The response has five or fewer unique values.  Are you sure you want to do regression?”
# Warning message in randomForest.default(x = obsX, y = obsY, ntree = ntree, mtry = mtry, :
# “The response has five or fewer unique values.  Are you sure you want to do regression?”
# Warning message in randomForest.default(x = obsX, y = obsY, ntree = ntree, mtry = mtry, :
# “The response has five or fewer unique values.  Are you sure you want to do regression?”
# Warning message in randomForest.default(x = obsX, y = obsY, ntree = ntree, mtry = mtry, :
# “The response has five or fewer unique values.  Are you sure you want to do regression?”
# Warning message in randomForest.default(x = obsX, y = obsY, ntree = ntree, mtry = mtry, :
# “The response has five or fewer unique values.  Are you sure you want to do regression?”
# Warning message in randomForest.default(x = obsX, y = obsY, ntree = ntree, mtry = mtry, :
# “The response has five or fewer unique values.  Are you sure you want to do regression?”
# Warning message in randomForest.default(x = obsX, y = obsY, ntree = ntree, mtry = mtry, :
# “The response has five or fewer unique values.  Are you sure you want to do regression?”
# [1] "Alleghany"
# Warning message in randomForest.default(x = obsX, y = obsY, ntree = ntree, mtry = mtry, :
# “The response has five or fewer unique values.  Are you sure you want to do regression?”
# Warning message in randomForest.default(x = obsX, y = obsY, ntree = ntree, mtry = mtry, :
# “The response has five or fewer unique values.  Are you sure you want to do regression?”
# [1] "Anson"
# Warning message in randomForest.default(x = obsX, y = obsY, ntree = ntree, mtry = mtry, :
# “The response has five or fewer unique values.  Are you sure you want to do regression?”
# Warning message in randomForest.default(x = obsX, y = obsY, ntree = ntree, mtry = mtry, :
# “The response has five or fewer unique values.  Are you sure you want to do regression?”
# Warning message in randomForest.default(x = obsX, y = obsY, ntree = ntree, mtry = mtry, :
# “The response has five or fewer unique values.  Are you sure you want to do regression?”
# Warning message in randomForest.default(x = obsX, y = obsY, ntree = ntree, mtry = mtry, :
# “The response has five or fewer unique values.  Are you sure you want to do regression?”
# Warning message in randomForest.default(x = obsX, y = obsY, ntree = ntree, mtry = mtry, :
# “The response has five or fewer unique values.  Are you sure you want to do regression?”
# Warning message in randomForest.default(x = obsX, y = obsY, ntree = ntree, mtry = mtry, :
# “The response has five or fewer unique values.  Are you sure you want to do regression?”
# Warning message in randomForest.default(x = obsX, y = obsY, ntree = ntree, mtry = mtry, :
# “The response has five or fewer unique values.  Are you sure you want to do regression?”
# Warning message in randomForest.default(x = obsX, y = obsY, ntree = ntree, mtry = mtry, :
# “The response has five or fewer unique values.  Are you sure you want to do regression?”
# Warning message in randomForest.default(x = obsX, y = obsY, ntree = ntree, mtry = mtry, :
# “The response has five or fewer unique values.  Are you sure you want to do regression?”
# Warning message in randomForest.default(x = obsX, y = obsY, ntree = ntree, mtry = mtry, :
# “The response has five or fewer unique values.  Are you sure you want to do regression?”
# Warning message in randomForest.default(x = obsX, y = obsY, ntree = ntree, mtry = mtry, :
# “The response has five or fewer unique values.  Are you sure you want to do regression?”
# Warning message in randomForest.default(x = obsX, y = obsY, ntree = ntree, mtry = mtry, :
# “The response has five or fewer unique values.  Are you sure you want to do regression?”
# [1] "Ashe"
# Warning message in randomForest.default(x = obsX, y = obsY, ntree = ntree, mtry = mtry, :
# “The response has five or fewer unique values.  Are you sure you want to do regression?”
# Warning message in randomForest.default(x = obsX, y = obsY, ntree = ntree, mtry = mtry, :
# “The response has five or fewer unique values.  Are you sure you want to do regression?”
# Warning message in randomForest.default(x = obsX, y = obsY, ntree = ntree, mtry = mtry, :
# “The response has five or fewer unique values.  Are you sure you want to do regression?”
# Error in if (n == 0) stop("data (x) has 0 rows"): argument is of length zero
# Traceback:
#
# 1. random_forest_imputation(acs_whp_df, variable_presence_df)
# 2. missForest(as.matrix(county_preimputed_df[, 4:length(variables_to_keep)]))   # at line 18 of file <text>
# 3. randomForest(x = obsX, y = obsY, ntree = ntree, mtry = mtry,
#  .     replace = replace, sampsize = if (!is.null(sampsize)) sampsize[[varInd]] else if (replace) nrow(obsX) else ceiling(0.632 *
#  .         nrow(obsX)), nodesize = if (!is.null(nodesize)) nodesize[1] else 1,
#  .     maxnodes = if (!is.null(maxnodes)) maxnodes else NULL)
# 4. randomForest.default(x = obsX, y = obsY, ntree = ntree, mtry = mtry,
#  .     replace = replace, sampsize = if (!is.null(sampsize)) sampsize[[varInd]] else if (replace) nrow(obsX) else ceiling(0.632 *
#  .         nrow(obsX)), nodesize = if (!is.null(nodesize)) nodesize[1] else 1,
#  .     maxnodes = if (!is.null(maxnodes)) maxnodes else NULL)

# %%
# exporting data
write.csv(imputed_df, paste0(Output,"/", cur_date, "_Imputed_ACS_WHP_Data.csv"), row.names = FALSE)
